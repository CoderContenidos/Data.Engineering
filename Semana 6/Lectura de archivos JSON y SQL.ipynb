# %% [markdown]
# # JSON file

# %%
import pandas as pd
pd.read_json('nested_json.json')
# Out:
#           school_name   class  \
# 0  ABC primary school  Year 1
# 1  ABC primary school  Year 1
# 2  ABC primary school  Year 1
#
#                                             students
# 0  {'id': 'A001', 'name': 'Tom', 'math': 60, 'phy...
# 1  {'id': 'A002', 'name': 'James', 'math': 89, 'p...
# 2  {'id': 'A003', 'name': 'Jenny', 'math': 79, 'p...

# %%
import json
# Normalizar los datos
with open('nested_json.json','r') as f:
    data = json.loads(f.read())# Flatten data
df_nested_list = pd.json_normalize(data, record_path =['students'])
df_nested_list
# Out:
#      id   name  math  physics  chemistry
# 0  A001    Tom    60       66         61
# 1  A002  James    89       76         51
# 2  A003  Jenny    79       90         78

# %%
# Combinando
df_nested_list = pd.json_normalize(
    data, 
    record_path =['students'], 
    meta=['school_name', 'class']
)
df_nested_list
# Out:
#      id   name  math  physics  chemistry         school_name   class
# 0  A001    Tom    60       66         61  ABC primary school  Year 1
# 1  A002  James    89       76         51  ABC primary school  Year 1
# 2  A003  Jenny    79       90         78  ABC primary school  Year 1

# %% [markdown]
# # SQL

# %%
import sqlite3 as sql
import pandas as pd
import matplotlib.pyplot as plt
conn= sql.connect('nba_salary.sqlite')
conn

# %%
# Visualizar las tablas
cursor = conn.cursor()
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
print(cursor. fetchall())
# Out:
# [('NBA_season1718_salary',), ('Seasons_Stats',)]

# %%
df_salary = pd.read_sql_query("SELECT * from NBA_season1718_salary", conn)
df_salary.head()
# Out:
#     X1          Player   Tm  season17_18
# 0  1.0   Stephen Curry  GSW   34682550.0
# 1  2.0    LeBron James  CLE   33285709.0
# 2  3.0    Paul Millsap  DEN   31269231.0
# 3  4.0  Gordon Hayward  BOS   29727900.0
# 4  5.0   Blake Griffin  DET   29512900.0

# %%
df_stats = pd.read_sql_query("SELECT * from Seasons_Stats", conn)
df_stats.head()
# Out:
#     X1    Year           Player  Pos   Age   Tm     G  GS  MP  PER  ...  \
# 0  0.0  1950.0  Curly Armstrong  G-F  31.0  FTW  63.0 NaN NaN  NaN  ...
# 1  1.0  1950.0     Cliff Barker   SG  29.0  INO  49.0 NaN NaN  NaN  ...
# 2  2.0  1950.0    Leo Barnhorst   SF  25.0  CHS  67.0 NaN NaN  NaN  ...
# 3  3.0  1950.0       Ed Bartels    F  24.0  TOT  15.0 NaN NaN  NaN  ...
# 4  4.0  1950.0       Ed Bartels    F  24.0  DNN  13.0 NaN NaN  NaN  ...
#
#      FT%  ORB  DRB  TRB    AST  STL  BLK  TOV     PF    PTS
# 0  0.705  NaN  NaN  NaN  176.0  NaN  NaN  NaN  217.0  458.0
# 1  0.708  NaN  NaN  NaN  109.0  NaN  NaN  NaN   99.0  279.0
# 2  0.698  NaN  NaN  NaN  140.0  NaN  NaN  NaN  192.0  438.0
# 3  0.559  NaN  NaN  NaN   20.0  NaN  NaN  NaN   29.0   63.0
# 4  0.548  NaN  NaN  NaN   20.0  NaN  NaN  NaN   27.0   59.0
#
# [5 rows x 53 columns]

# %%
df_stats.columns
# Out:
# Index(['X1', 'Year', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'PER',
#        'TS%', '3PAr', 'FTr', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%',
#        'TOV%', 'USG%', 'blanl', 'OWS', 'DWS', 'WS', 'WS/48', 'blank2', 'OBPM',
#        'DBPM', 'BPM', 'VORP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', '2P',
#        '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST',
#        'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
# Ordenar jugadores por mayor cantidad de puntos totales
df_stats.sort_values(by='PTS',ascending=False)
# Out:
#             X1    Year             Player   Pos   Age    Tm     G  GS      MP  \
# 1706    1706.0  1962.0  Wilt Chamberlain*     C  25.0   PHW  80.0 NaN  3882.0
# 1827    1827.0  1963.0  Wilt Chamberlain*     C  26.0   SFW  80.0 NaN  3806.0
# 8469    8469.0  1987.0    Michael Jordan*    SG  23.0   CHI  82.0 NaN  3281.0
# 1593    1593.0  1961.0  Wilt Chamberlain*     C  24.0   PHW  79.0 NaN  3773.0
# 1962    1962.0  1964.0  Wilt Chamberlain*     C  27.0   SFW  80.0 NaN  3689.0
# ...        ...     ...                ...   ...   ...   ...   ...  ..     ...
# 21678  21678.0     NaN               None  None   NaN  None   NaN NaN     NaN
# 22252  22252.0     NaN               None  None   NaN  None   NaN NaN     NaN
# 22864  22864.0     NaN               None  None   NaN  None   NaN NaN     NaN
# 23516  23516.0     NaN               None  None   NaN  None   NaN NaN     NaN
# 24095  24095.0     NaN               None  None   NaN  None   NaN NaN     NaN
#
#         PER  ...    FT%  ORB  DRB     TRB    AST  STL  BLK  TOV     PF     PTS
# 1706   31.7  ...  0.613  NaN  NaN  2052.0  192.0  NaN  NaN  NaN  123.0  4029.0
# 1827   31.8  ...  0.593  NaN  NaN  1946.0  275.0  NaN  NaN  NaN  136.0  3586.0
# 8469   29.8  ...  0.857  NaN  NaN   430.0  377.0  NaN  NaN  NaN  237.0  3041.0
# 1593   27.8  ...  0.504  NaN  NaN  2149.0  148.0  NaN  NaN  NaN  130.0  3033.0
# 1962   31.6  ...  0.531  NaN  NaN  1787.0  403.0  NaN  NaN  NaN  182.0  2948.0
# ...     ...  ...    ...  ...  ...     ...    ...  ...  ...  ...    ...     ...
# 21678   NaN  ...    NaN  NaN  NaN     NaN    NaN  NaN  NaN  NaN    NaN     NaN
# 22252   NaN  ...    NaN  NaN  NaN     NaN    NaN  NaN  NaN  NaN    NaN     NaN
# 22864   NaN  ...    NaN  NaN  NaN     NaN    NaN  NaN  NaN  NaN    NaN     NaN
# 23516   NaN  ...    NaN  NaN  NaN     NaN    NaN  NaN  NaN  NaN    NaN     NaN
# 24095   NaN  ...    NaN  NaN  NaN     NaN    NaN  NaN  NaN  NaN    NaN     NaN
#
# [24691 rows x 53 columns]
