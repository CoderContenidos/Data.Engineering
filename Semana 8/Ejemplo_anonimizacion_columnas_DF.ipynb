# %%
# !pip install anonymizedf
# Out:
# Collecting anonymizedf
#   Downloading anonymizedf-1.0.1-py3-none-any.whl (7.0 kB)
# Collecting faker
#   Downloading Faker-14.2.0-py3-none-any.whl (1.6 MB)
# Requirement already satisfied: pandas in c:\users\windows\anaconda3\lib\site-packages (from anonymizedf) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.4 in c:\users\windows\anaconda3\lib\site-packages (from faker->anonymizedf) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\windows\anaconda3\lib\site-packages (from python-dateutil>=2.4->faker->anonymizedf) (1.16.0)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\windows\anaconda3\lib\site-packages (from pandas->anonymizedf) (1.21.5)
# Requirement already satisfied: pytz>=2020.1 in c:\users\windows\anaconda3\lib\site-packages (from pandas->anonymizedf) (2021.3)
# Installing collected packages: faker, anonymizedf
# Successfully installed anonymizedf-1.0.1 faker-14.2.0

# %%
import pandas as pd
from anonymizedf.anonymizedf import anonymize
# Importar la data
df = pd.read_csv("https://query.data.world/s/shcktxndtu3ojonm46tb5udlz7sp3e")
df
# Out:
#     Customer ID       Customer Name  Loyalty Reward Points    Segment  \
# 0      AA-10315          Alex Avila                     76   Consumer
# 1      AA-10375        Allen Armold                    369   Consumer
# 2      AA-10480        Andrew Allen                    162   Consumer
# 3      AA-10645       Anna Andreadi                    803   Consumer
# 4      AB-10015       Aaron Bergman                    935   Consumer
# ..          ...                 ...                    ...        ...
# 788    XP-21865        Xylona Preis                    454   Consumer
# 789    YC-21895      Yoseph Carroll                    935  Corporate
# 790    YS-21880       Yana Sorensen                    829  Corporate
# 791    ZC-21910    Zuschuss Carroll                    745   Consumer
# 792    ZD-21925  Zuschuss Donatelli                     85   Consumer
#
#            Date  Fraction
# 0    01/01/2000       7.6
# 1    02/01/2000      36.9
# 2    03/01/2000      16.2
# 3    04/01/2000      80.3
# 4    05/01/2000      93.5
# ..          ...       ...
# 788  27/02/2002      45.4
# 789  28/02/2002      93.5
# 790  01/03/2002      82.9
# 791  02/03/2002      74.5
# 792  03/03/2002       8.5
#
# [793 rows x 6 columns]

# %%
# Preparar la data a ser anonimizada
an = anonymize(df)
an

# %% [markdown]
# # Forma 1: Modificacion uno a uno

# %%
an.fake_names("Customer Name")
an.fake_ids("Customer ID")
an.fake_whole_numbers("Loyalty Reward Points")
an.fake_categories("Segment")
an.fake_dates("Date")
an.fake_decimal_numbers("Fraction")
# Out:
#     Customer ID       Customer Name  Loyalty Reward Points    Segment  \
# 0      AA-10315          Alex Avila                     76   Consumer
# 1      AA-10375        Allen Armold                    369   Consumer
# 2      AA-10480        Andrew Allen                    162   Consumer
# 3      AA-10645       Anna Andreadi                    803   Consumer
# 4      AB-10015       Aaron Bergman                    935   Consumer
# ..          ...                 ...                    ...        ...
# 788    XP-21865        Xylona Preis                    454   Consumer
# 789    YC-21895      Yoseph Carroll                    935  Corporate
# 790    YS-21880       Yana Sorensen                    829  Corporate
# 791    ZC-21910    Zuschuss Carroll                    745   Consumer
# 792    ZD-21925  Zuschuss Donatelli                     85   Consumer
#
#            Date  Fraction    Fake_Customer Name    Fake_Customer ID  \
# 0    01/01/2000       7.6      Carole Schofield  SJUL50700663409124
# 1    02/01/2000      36.9  Janice Shaw-Williams  AYHV78464046190420
# 2    03/01/2000      16.2         Dr Dean Allen  LKFH85508050014520
# 3    04/01/2000      80.3     Janet Rees-Sutton  FVQP15615384996622
# 4    05/01/2000      93.5      Jonathan Roberts  MTNA56213382276075
# ..          ...       ...                   ...                 ...
# 788  27/02/2002      45.4  Jane Clements-Mellor  NJSW45403152432487
# 789  28/02/2002      93.5          Simon Morton  LSOV93655391489472
# 790  01/03/2002      82.9        Mr Brian Davis  USFG45266339387502
# 791  02/03/2002      74.5          Wayne Foster  BWQY76321159612800
# 792  03/03/2002       8.5     Mr Clifford Green  HWFN07677562042186
#
#      Fake_Loyalty Reward Points Fake_Segment   Fake_Date  Fake_Fraction
# 0                           523    Segment 1  1983-04-21          61.76
# 1                           698    Segment 1  1998-07-25          69.33
# 2                           368    Segment 1  1970-04-22          11.33
# 3                           111    Segment 1  1991-04-28           9.67
# 4                           113    Segment 1  2010-05-31          33.66
# ..                          ...          ...         ...            ...
# 788                         389    Segment 1  1987-12-29          87.41
# 789                         113    Segment 3  1979-02-16          33.66
# 790                         137    Segment 3  2017-10-13          83.32
# 791                         552    Segment 1  2015-12-18          80.28
# 792                         110    Segment 1  1981-05-14          17.22
#
# [793 rows x 12 columns]

# %%
df
# Out:
#     Customer ID       Customer Name  Loyalty Reward Points    Segment  \
# 0      AA-10315          Alex Avila                     76   Consumer
# 1      AA-10375        Allen Armold                    369   Consumer
# 2      AA-10480        Andrew Allen                    162   Consumer
# 3      AA-10645       Anna Andreadi                    803   Consumer
# 4      AB-10015       Aaron Bergman                    935   Consumer
# ..          ...                 ...                    ...        ...
# 788    XP-21865        Xylona Preis                    454   Consumer
# 789    YC-21895      Yoseph Carroll                    935  Corporate
# 790    YS-21880       Yana Sorensen                    829  Corporate
# 791    ZC-21910    Zuschuss Carroll                    745   Consumer
# 792    ZD-21925  Zuschuss Donatelli                     85   Consumer
#
#            Date  Fraction    Fake_Customer Name    Fake_Customer ID  \
# 0    01/01/2000       7.6      Carole Schofield  SJUL50700663409124
# 1    02/01/2000      36.9  Janice Shaw-Williams  AYHV78464046190420
# 2    03/01/2000      16.2         Dr Dean Allen  LKFH85508050014520
# 3    04/01/2000      80.3     Janet Rees-Sutton  FVQP15615384996622
# 4    05/01/2000      93.5      Jonathan Roberts  MTNA56213382276075
# ..          ...       ...                   ...                 ...
# 788  27/02/2002      45.4  Jane Clements-Mellor  NJSW45403152432487
# 789  28/02/2002      93.5          Simon Morton  LSOV93655391489472
# 790  01/03/2002      82.9        Mr Brian Davis  USFG45266339387502
# 791  02/03/2002      74.5          Wayne Foster  BWQY76321159612800
# 792  03/03/2002       8.5     Mr Clifford Green  HWFN07677562042186
#
#      Fake_Loyalty Reward Points Fake_Segment   Fake_Date  Fake_Fraction
# 0                           523    Segment 1  1983-04-21          61.76
# 1                           698    Segment 1  1998-07-25          69.33
# 2                           368    Segment 1  1970-04-22          11.33
# 3                           111    Segment 1  1991-04-28           9.67
# 4                           113    Segment 1  2010-05-31          33.66
# ..                          ...          ...         ...            ...
# 788                         389    Segment 1  1987-12-29          87.41
# 789                         113    Segment 3  1979-02-16          33.66
# 790                         137    Segment 3  2017-10-13          83.32
# 791                         552    Segment 1  2015-12-18          80.28
# 792                         110    Segment 1  1981-05-14          17.22
#
# [793 rows x 12 columns]

# %% [markdown]
# # Forma 2: Cadenas

# %%
fake_df = (
    an
    .fake_names("Customer Name", chaining=True)
    .fake_ids("Customer ID", chaining=True)
    .fake_whole_numbers("Loyalty Reward Points", chaining=True)
    .fake_categories("Segment", chaining=True)
    .fake_dates("Date", chaining=True)
    .fake_decimal_numbers("Fraction", chaining=True)
    .show_data_frame()
)
fake_df
# Out:
#     Customer ID       Customer Name  Loyalty Reward Points    Segment  \
# 0      AA-10315          Alex Avila                     76   Consumer
# 1      AA-10375        Allen Armold                    369   Consumer
# 2      AA-10480        Andrew Allen                    162   Consumer
# 3      AA-10645       Anna Andreadi                    803   Consumer
# 4      AB-10015       Aaron Bergman                    935   Consumer
# ..          ...                 ...                    ...        ...
# 788    XP-21865        Xylona Preis                    454   Consumer
# 789    YC-21895      Yoseph Carroll                    935  Corporate
# 790    YS-21880       Yana Sorensen                    829  Corporate
# 791    ZC-21910    Zuschuss Carroll                    745   Consumer
# 792    ZD-21925  Zuschuss Donatelli                     85   Consumer
#
#            Date  Fraction    Fake_Customer Name    Fake_Customer ID  \
# 0    01/01/2000       7.6      Cameron Mitchell  PBFV56072398058073
# 1    02/01/2000      36.9       Mr Aaron Barlow  BVCN26299897685255
# 2    03/01/2000      16.2          Megan Davies  IVVF35174418467776
# 3    04/01/2000      80.3     Mr Gerald Skinner  MIDL31315324379714
# 4    05/01/2000      93.5        Graham Freeman  EGJN90079683660871
# ..          ...       ...                   ...                 ...
# 788  27/02/2002      45.4     Miss Hayley Lewis  CKYI27932236342043
# 789  28/02/2002      93.5    Laura Curtis-Poole  XMKJ64472828132256
# 790  01/03/2002      82.9          Martin Price  YMKL93073994883471
# 791  02/03/2002      74.5  Mr Mohammad Shepherd  XEHP14315049374838
# 792  03/03/2002       8.5         Nigel Elliott  KZCF22746663345226
#
#      Fake_Loyalty Reward Points Fake_Segment   Fake_Date  Fake_Fraction
# 0                           388    Segment 1  2018-08-01           0.18
# 1                           191    Segment 1  1976-02-08          23.91
# 2                           780    Segment 1  1996-10-22           9.97
# 3                            93    Segment 1  2008-10-21          28.78
# 4                           965    Segment 1  1979-05-18          23.65
# ..                          ...          ...         ...            ...
# 788                         838    Segment 1  1988-12-18          40.96
# 789                         965    Segment 3  2017-07-01          23.65
# 790                         356    Segment 3  2002-07-13          89.31
# 791                         991    Segment 1  2014-04-22          47.57
# 792                         219    Segment 1  2009-06-15          25.10
#
# [793 rows x 12 columns]

# %% [markdown]
# # Forma 3: Asignacion multiple

# %%
fake_df = an.fake_names("Customer Name")
fake_df = an.fake_ids("Customer ID")
fake_df = an.fake_whole_numbers("Loyalty Reward Points")
fake_df = an.fake_categories("Segment")
fake_df = an.fake_dates("Date")
fake_df = an.fake_decimal_numbers("Fraction")
fake_df
# Out:
#     Customer ID       Customer Name  Loyalty Reward Points    Segment  \
# 0      AA-10315          Alex Avila                     76   Consumer
# 1      AA-10375        Allen Armold                    369   Consumer
# 2      AA-10480        Andrew Allen                    162   Consumer
# 3      AA-10645       Anna Andreadi                    803   Consumer
# 4      AB-10015       Aaron Bergman                    935   Consumer
# ..          ...                 ...                    ...        ...
# 788    XP-21865        Xylona Preis                    454   Consumer
# 789    YC-21895      Yoseph Carroll                    935  Corporate
# 790    YS-21880       Yana Sorensen                    829  Corporate
# 791    ZC-21910    Zuschuss Carroll                    745   Consumer
# 792    ZD-21925  Zuschuss Donatelli                     85   Consumer
#
#            Date  Fraction    Fake_Customer Name    Fake_Customer ID  \
# 0    01/01/2000       7.6         Leonard Allen  LGYF67707793634412
# 1    02/01/2000      36.9      Dr Howard Taylor  GJTJ42971795836444
# 2    03/01/2000      16.2           Marc Burton  IXNA14143260895899
# 3    04/01/2000      80.3             Jodie Lee  FYYD93615140335994
# 4    05/01/2000      93.5  Miss Annette Chapman  WTEN50740968961153
# ..          ...       ...                   ...                 ...
# 788  27/02/2002      45.4            Ruth Patel  RYIH56975394046970
# 789  28/02/2002      93.5         Duncan McLean  ZLLR36905876820237
# 790  01/03/2002      82.9      Mr Jeremy Thomas  PYYY65084370971858
# 791  02/03/2002      74.5         Dr Simon Ball  ZZMK46684366702221
# 792  03/03/2002       8.5           Marian Carr  NJSZ53885646776627
#
#      Fake_Loyalty Reward Points Fake_Segment   Fake_Date  Fake_Fraction
# 0                            30    Segment 1  1986-01-01          35.91
# 1                           109    Segment 1  2008-11-07          55.76
# 2                            33    Segment 1  2006-12-03          32.72
# 3                           600    Segment 1  2008-09-16          56.94
# 4                           468    Segment 1  1995-03-13          29.07
# ..                          ...          ...         ...            ...
# 788                         846    Segment 1  1973-04-17          28.53
# 789                         468    Segment 3  2005-10-01          29.07
# 790                          48    Segment 3  1984-06-05          48.70
# 791                         140    Segment 1  2017-11-12          50.91
# 792                         106    Segment 1  1984-07-18          44.22
#
# [793 rows x 12 columns]
